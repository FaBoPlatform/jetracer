# %%
from pathlib import Path
import pandas as pd

# %%
# parquet_path = "/home/jetson/notebooks/notebooks/dataset/dataset_gimmick_parking/dataset_v1.parquet"
parquet_path = "/home/jetson/notebooks/notebooks/detect/dataset_gimmick_env/dataset_v1.parquet"

# %%
df = pd.read_parquet(parquet_path)

# %%
df
# Out:
#                                                  出力先パス  \
# 0    detect/dataset_gimmick_env/ROAD/fb335126-b061-...
# 1    detect/dataset_gimmick_env/GATE_RIGHT/192a85a0...
# 2    detect/dataset_gimmick_env/GATE_RIGHT/1da563de...
# 3    detect/dataset_gimmick_env/GATE_RIGHT/1f90d502...
# 4    detect/dataset_gimmick_env/GATE_RIGHT/20ebf1c0...
# ..                                                 ...
# 371  detect/dataset_gimmick_env/PARKING/83d170e2-b0...
# 372  detect/dataset_gimmick_env/START_3/8b3a1adc-b0...
# 373  detect/dataset_gimmick_env/START_3/9171fcc6-b0...
# 374  detect/dataset_gimmick_env/START_3/a44e0ad8-b0...
# 375  detect/dataset_gimmick_env/START_3/b4311760-b0...
#
#                                                 入力画像パス  InX  InY  InFrameNum  \
# 0    camera/eval_gimmick_202510221123_cam1/xy/0_0_0...    0    0         399
# 1    camera/eval_gimmick_202510221123_cam1/xy/0_0_0...    0    0         405
# ...

# %% [markdown]
# ## 除外

# %%
# delete = [
#     "0_112_299e4142-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_56_39924ec2-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_56_3e4a0acc-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_84_52d440ca-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_112_5a5b05b8-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_82_6010dc30-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_86_64543a44-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_103_7f7e534a-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_127_86e5ad2c-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_83_a1c67996-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_85_a5663aaa-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_83_a79dc6e4-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_83_aa8af73c-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_112_aea1b4d2-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_113_b2a706cc-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_140_b54dfade-af4f-11f0-951f-53adccf0eecb.jpg",
#     "0_140_b83d74e0-af4f-11f0-951f-53adccf0eecb.jpg",
# ]
# new_df = df[~df["出力先パス"].map(lambda x: Path(x).name).isin(delete)]
new_df = df[~df["入力画像パス"].map(lambda x: "camera/eval_gimmick_parking_202510231710" in x)]
display(new_df)
# print(new_df["出力先パス"].tolist())
# Out:
#                                                  出力先パス  \
# 0    detect/dataset_gimmick_env/ROAD/fb335126-b061-...
# 1    detect/dataset_gimmick_env/GATE_RIGHT/192a85a0...
# 2    detect/dataset_gimmick_env/GATE_RIGHT/1da563de...
# 3    detect/dataset_gimmick_env/GATE_RIGHT/1f90d502...
# 4    detect/dataset_gimmick_env/GATE_RIGHT/20ebf1c0...
# ..                                                 ...
# 366  detect/dataset_gimmick_env/GATE_CENTER/f210eae...
# 367  detect/dataset_gimmick_env/GATE_CENTER/01a07bf...
# 368  detect/dataset_gimmick_env/GATE_CENTER/0c675c7...
# 369  detect/dataset_gimmick_env/ROAD/195a4e78-b087-...
# 370  detect/dataset_gimmick_env/ROAD/209e824e-b087-...
#
#                                                 入力画像パス  InX  InY  InFrameNum  \
# 0    camera/eval_gimmick_202510221123_cam1/xy/0_0_0...    0    0         399
# 1    camera/eval_gimmick_202510221123_cam1/xy/0_0_0...    0    0         405
# ...

# %%
# new_df.to_parquet(parquet_path)

# %% [markdown]
# ## ソート

# %%
new_df = df.sort_values(by=["入力画像パス", "InFrameNum", "値種別"])
new_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_209079/3675389136.py in ?()
# ----> 1 new_df = df.sort_values(by=["入力画像パス", "InFrameNum", "値種別"])
#       2 new_df
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7190                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7191                 f" != length of by ({len(by)})"
#    7192             )
#    7193         if len(by) > 1:
# -> 7194             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7195
#    7196             # need to rewrap columns in Series to apply key function
#    7197             if key is not None:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(.0)
# ...

# %%
# new_df.to_parquet(parquet_path)

# %% [markdown]
# ## ユニーク値

# %%
from pathlib import Path

pd.unique(df["入力画像パス"].map(lambda x: Path(x).parts[:2]))
# Out:
# array([('camera', 'eval_gimmick_202510221123_cam1')], dtype=object)
